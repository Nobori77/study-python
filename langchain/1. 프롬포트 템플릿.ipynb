# %%
from dotenv import load_dotenv
import os

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")[:10]

# %%
OPENAI_API_KEY
# Out:
# 'sk-proj-gm'

# %%
from langchain_openai.chat_models.base import ChatOpenAI

# %%
# OPENAI_API_KEY
# chat = ChatOpenAI(api_key=OPENAI_API_KEY)
chat = ChatOpenAI()

# %%
chat.invoke("너는 어떤 버전의 모델이니?")
# Out:
# AIMessage(content='저는 GPT-3라는 모델을 기반으로 동작하는 인공지능 모델입니다. 따라서 그 이상의 세부 정보는 알려드릴 수 없습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 24, 'total_tokens': 78, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DeZrYQvTEMrAQLxkabyPW2pZLSdk9', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e1aa2-f254-7371-979e-8f3b00f2b5b7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 24, 'output_tokens': 54, 'total_tokens': 78, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
chat.invoke("내 이름은 길동이야, 내 이름은 뮈니?")
# Out:
# AIMessage(content='죄송합니다, 지금 입력하신 이름은 "뮈니"로 도움을 드릴 수 없습니다. 본인의 실수일 가능성이 있습니다. 그렇지 않다면, 다시 한번 이름을 입력해 주시거나 다른 도움이 필요한 내용이 있으시면 말씀해주세요. 감사합니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 99, 'prompt_tokens': 24, 'total_tokens': 123, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DeZzOU0boNZ2mYogOPGYs5CmHHFmW', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e1aaa-5f7a-7db0-9924-ff08e0d4ef67-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 24, 'output_tokens': 99, 'total_tokens': 123, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ## LLM 모델과 Chat 모델

# %%
# llm
from langchain_openai.llms.base import OpenAI

# %%
llm = OpenAI()

# %%
# .invoke(): llm에게 프롬프트를 전달하는 메서드
result = llm.invoke("태양계는 얼마나 많은 행성들을 가지고 있니?")

# %%
print(result)
# Out:
# 태양계는 8개의 행성을 가지고 있습니다. 이들은 수성, 금성, 지구, 화성, 목성, 토성, 천왕성, 해왕성입니다.

# %%
llm.model_name
# Out:
# 'gpt-3.5-turbo-instruct'

# %%
chat = ChatOpenAI()

# %%
chat.model_name
# Out:
# 'gpt-3.5-turbo'

# %%
result2 = chat.invoke("How many planets are there?")

# %%
result2.content
# Out:
# 'There are currently eight recognized planets in our solar system: Mercury, Venus, Earth, Mars, Jupiter, Saturn, Uranus, and Neptune.'

# %%
result2
# Out:
# AIMessage(content='There are currently eight recognized planets in our solar system: Mercury, Venus, Earth, Mars, Jupiter, Saturn, Uranus, and Neptune.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 29, 'prompt_tokens': 13, 'total_tokens': 42, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DeafWIuVAx0y4G86o0vC2D0W86VtO', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e1ad2-3b16-74c2-af65-599dcf7d1f19-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 29, 'total_tokens': 42, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# v1.2.6
# 사용자가 입력한 프롬프트를 전달하는 객체
from langchain_core.messages.human import HumanMessage

# llm 지침, 답변 유도, 컨텍스트를 전달하는 객체
from langchain_core.messages.system import SystemMessage

# AI 의 답변 객체
from langchain_core.messages.ai import AIMessage

# %%
# Messages: Chat모델에게 전달되는 프롬프트 객체
messages = [
    SystemMessage(content="너는 지리학 전문가이며, 한국어로 답변해줘!"),
    HumanMessage(content="How many planets are there?")
]

# %%
result = chat.invoke(messages)

# %%
result.content
# Out:
# '현재 태양계에는 8개의 행성이 있습니다. 이들은 수성, 금성, 지구, 화성, 목성, 토성, 천왕성, 네프튠스 입니다. 추가로 소행성이나 왜행성 같은 작은 천체들도 존재합니다.'

# %% [markdown]
# ## PromptTemplate, ChatPromptTemplate

# %%
from langchain_core.prompts.prompt import PromptTemplate
from langchain_core.prompts.chat import ChatPromptTemplate

# %%
template = PromptTemplate.from_template("{country_a}에서 {cuntry_b}까지의 거리를 알려줘")

# input_variables=[]: 템플릿의 변수들
print(template)
# Out:
# input_variables=['country_a', 'cuntry_b'] input_types={} partial_variables={} template='{country_a}에서 {cuntry_b}까지의 거리를 알려줘'

# %%
prompt = template.format(country_a="일본", cuntry_b="한국")

prompt
# Out:
# '일본에서 한국까지의 거리를 알려줘'

# %%
result = chat.invoke(prompt)

# %%
result.content
# Out:
# '일본과 한국 간의 거리는 일본의 도시와 한국의 도시에 따라 다르지만, 가장 일반적인 거리는 대한민국 서울과 일본 도쿄 간의 거리입니다. 이 두 도시 사이의 거리는 약 1,200km 정도이며, 비행기로 이동하는 경우 약 2시간 정도 소요됩니다.육로로 이동하는 경우에는 배편 혹은 기차를 이용하여 이동할 수 있습니다.'

# %%
chat_template = ChatPromptTemplate.from_messages([
    ("system", "너는 지리학 전문가야 그리고 오직 {language}언어로 답변해줘"),
    ("human", "{country_a}에서 {cuntry_b}까지의 거리를 알려줘."),
])

# %%
chat_template
# Out:
# ChatPromptTemplate(input_variables=['country_a', 'cuntry_b', 'language'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['language'], input_types={}, partial_variables={}, template='너는 지리학 전문가야 그리고 오직 {language}언어로 답변해줘'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['country_a', 'cuntry_b'], input_types={}, partial_variables={}, template='{country_a}에서 {cuntry_b}까지의 거리를 알려줘.'), additional_kwargs={})])

# %%
chat_prompt = chat_template.format(country_a="멕시코", cuntry_b="남아프리카공화국", language="한국어")

chat_prompt
# Out:
# 'System: 너는 지리학 전문가야 그리고 오직 한국어언어로 답변해줘\nHuman: 멕시코에서 남아프리카공화국까지의 거리를 알려줘.'

# %%
result = chat.invoke(chat_prompt)

# %%
result.content
# Out:
# '죄송합니다, 제가 거리를 정확히 계산해드릴 수는 없지만 멕시코에서 남아프리카까지는 약 15,000km 정도 떨어져 있습니다. 지구상에서 매우 먼 거리에 위치한 나라들이기 때문에 비행기를 이용하여 이동하는 것이 보통입니다.'

# %%
# '죄송합니다, 제가 거리를 정확히 계산해드릴 수는 없지만 
# 멕시코에서 남아프리카까지는 약 15,000km 정도 떨어져 있습니다. 
# 지구상에서 매우 먼 거리에 위치한 나라들이기 때문에 비행기를 이용하여 이동하는 것이 보통입니다.'

# %% [markdown]
# ## OutParser

# %%
# LLM -> 파이썬 List
from langchain_core.output_parsers.base import BaseOutputParser

# OutParser를 제작하기 위해서는 BaseOutputParser 상속받아야 한다

# %%
class CommaOutPutParser(BaseOutputParser):
    # parse(): 반드시 재정의
    def parse(self, text):
        return list(map(str.strip, text.split(",")))

# %%
comma_parser = CommaOutPutParser()

# %%
comma_parser.parse("안녕,                나는,         홍,    길동, 이야")
# Out:
# ['안녕', '나는', '홍', '길동', '이야']

# %%
template = ChatPromptTemplate.from_messages([
    ("system", """ 
        리스트를 생성하는 기계입니다.
        요청한 모든 리스트에 개수는 최대 {max_length}개 까지만 목록으로 표시하세요.
        그 이상 초과되는 리스트는 답변하지 마세요.
    """),
    ("human", "{question}")
])

# %%
prompt = template.format_messages(
    max_length= 5,
    question="태양계 행성의 종류를 알려줘"
)

# %%
print(prompt)
# Out:
# [SystemMessage(content=' \n        리스트를 생성하는 기계입니다.\n        요청한 모든 리스트에 개수는 최대 5개 까지만 목록으로 표시하세요.\n        그 이상 초과되는 리스트는 답변하지 마세요.\n    ', additional_kwargs={}, response_metadata={}), HumanMessage(content='태양계 행성의 종류를 알려줘', additional_kwargs={}, response_metadata={})]

# %%
result = chat.invoke(prompt)

# %%
output_list = comma_parser.parse(result.content)

print(output_list)
for i in output_list:
    print(i)
# Out:
# ['1. 수성\n2. 금성\n3. 지구\n4. 화성\n5. 목성']
# 1. 수성
# 2. 금성
# 3. 지구
# 4. 화성
# 5. 목성

# %%
"""
    기본 동작 (Legacy)
    template -> format -> invoke -> parser

    * LCEL 권장
    
"""

None
