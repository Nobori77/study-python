# %%
from dotenv import load_dotenv
import os

load_dotenv()
print(os.environ.get('OPENAI_API_KEY')[:20])

from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts.prompt import PromptTemplate
from langchain_core.prompts.chat import ChatPromptTemplate
# Out:
# sk-proj-gmk90JKmSW4I

# %%
chat = ChatOpenAI(temperature=0)

# %%
chat.invoke("게는 누구의 후손이니?")
# Out:
# AIMessage(content='게는 고대 신화에서 태양신 하이페리온(Hyperion)과 지구신 테아(Tea)의 후손으로 묘사되었습니다. 이들은 티탄(Titan) 신들의 일원으로, 그들의 후손 중 하나가 바로 게입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 83, 'prompt_tokens': 20, 'total_tokens': 103, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIsf4ik6Vhr9uIMlMHi2GUKapblC', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24f3-7b74-70d2-9458-61c62db2d208-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 20, 'output_tokens': 83, 'total_tokens': 103, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
chat.invoke("이음이라는 서비스는 어떤 서비스야? 공식 사이트 주소 줘")
# Out:
# AIMessage(content='죄송합니다. "이음"이라는 서비스에 대한 정보를 찾을 수 없습니다. 더 자세한 정보를 제공해주시면 도움을 드릴 수 있을 것 같습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 59, 'prompt_tokens': 36, 'total_tokens': 95, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIv8VFuv27IOhIlN8h4hs9z3qVT9', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24f5-d1e2-7a71-b565-e471a9149b13-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 36, 'output_tokens': 59, 'total_tokens': 95, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
chat.invoke("페일로그는 어떤 서비스야? 공식 사이트 주소 줘")
# Out:
# AIMessage(content='죄송합니다, 제가 알고 있는 정보에는 "페일로그"라는 서비스에 대한 정보가 없습니다. 혹시 다른 정보나 질문이 있으시다면 알려주세요. 도와드리겠습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 67, 'prompt_tokens': 37, 'total_tokens': 104, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIvJFzaDyvchlVGP30Hfm16kU2rp', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24f5-fa19-7383-81d1-2cd7605ab79b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 37, 'output_tokens': 67, 'total_tokens': 104, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ## ConversationBufferMemory

# %%
from langchain_classic.memory import ConversationBufferMemory

# %%
memory = ConversationBufferMemory()
# Out:
# C:\Users\Nobori\AppData\Local\Temp\ipykernel_21692\995385594.py:1: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferMemory()

# %%
memory.save_context(
    {"input": "Hi"},
    {"output": "How are you?"}
)

# %%
print(memory.load_memory_variables({}))
# Out:
# {'history': []}

# %% [markdown]
# ## return_messages = True
# - history 갹채애  AllMessage, HumanMessage로 저장하게 만든다

# %%
memory = ConversationBufferMemory(return_messages=True)

# %%
memory.save_context(
    {"input": "Hi"},
    {"output": "How are you?"}
)

# %%
print(memory.load_memory_variables({}))
# Out:
# {'history': [HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}), AIMessage(content='How are you?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]}

# %% [markdown]
# ## 문제점

# %%
chat = ChatOpenAI(temperature=0.1)

# %%
chat.invoke("내 이름은 길동이야")
# Out:
# AIMessage(content='반가워, 길동이! 무엇을 도와드릴까?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 16, 'total_tokens': 41, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfJUNa15prjhoBbODF9jUNThg1h4C', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e2517-258a-71c2-860a-3a47672030e7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 25, 'total_tokens': 41, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
chat.invoke("내 이름이 뭐야?")
# Out:
# AIMessage(content='죄송합니다, 저는 이름이 없는 인공지능 챗봇입니다. 어떻게 도와드릴까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 42, 'prompt_tokens': 14, 'total_tokens': 56, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfJUxu9OTbOINQjrx99JPe06s32x1', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e2517-b59d-7013-895b-ff7bbd6373bd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 42, 'total_tokens': 56, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ## 체인

# %%
from langchain_classic.chains import ConversationChain

# %%
llm = ChatOpenAI(temperature=0.1)
memory = ConversationBufferMemory(return_messages=True)

chain = ConversationChain(llm=llm, memory=memory)

# %%
result = chain.invoke("내이름은 길동이야")

# %%
result["response"]
# Out:
# '안녕하세요, 길동님! 만나서 반가워요. 저는 인공지능 어시스턴트입니다. 어떻게 도와드릴까요?'

# %%
result = chain.invoke("내이름이 뭐라고?")

# %%
result["response"]
# Out:
# '죄송합니다, 길동님. 제가 당신의 이름을 알 수는 없어요. 이름을 다시 말씀해주시겠어요?'

# %%
def print_memory():
    print(memory.load_memory_variables({}))

# %%
print_memory()
# Out:
# {'history': [HumanMessage(content='내이름은 길동이야', additional_kwargs={}, response_metadata={}), AIMessage(content='안녕하세요, 길동님! 만나서 반가워요. 저는 인공지능 어시스턴트입니다. 어떻게 도와드릴까요?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='내이름이 뭐라고?', additional_kwargs={}, response_metadata={}), AIMessage(content='죄송합니다, 길동님. 제가 당신의 이름을 알 수는 없어요. 이름을 다시 말씀해주시겠어요?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]}

# %% [markdown]
# ## ConversationBufferWindowMemory

# %%
from langchain_classic.memory import ConversationBufferWindowMemory

# %%
memory = ConversationBufferWindowMemory(return_messages=True, k=4)
# Out:
# C:\Users\Nobori\AppData\Local\Temp\ipykernel_21692\524726788.py:1: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferWindowMemory(return_messages=True, k=4)

# %%
memory.save_context(
    {"input": "1"},
    {"output": "1"}
)
memory.save_context(
    {"input": "2"},
    {"output": "2"}
)
memory.save_context(
    {"input": "3"},
    {"output": "3"}
)
memory.save_context(
    {"input": "4"},
    {"output": "4"}
)
memory.save_context(
    {"input": "5"},
    {"output": "5"}
)
memory.save_context(
    {"input": "6"},
    {"output": "6"}
)

# %%
print_memory()
# Out:
# {'history': [HumanMessage(content='3', additional_kwargs={}, response_metadata={}), AIMessage(content='3', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='4', additional_kwargs={}, response_metadata={}), AIMessage(content='4', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='5', additional_kwargs={}, response_metadata={}), AIMessage(content='5', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='6', additional_kwargs={}, response_metadata={}), AIMessage(content='6', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]}

# %%
memory = ConversationBufferWindowMemory(return_messages=True, k=4)

chain = ConversationChain(llm=llm, memory=memory)

# %%
chain.invoke("내 이름은 길동이야")
chain.invoke("피자는 어떻게 만들어?")
chain.invoke("개의 조상이 뭐야?")
chain.invoke("김세종은 일본에 갈 수 있어?")
chain.invoke("문윤성의 반댓말은?")
chain.invoke("예스규호는 어떤 일을 할 것 같아?")

chain.invoke("내 이름이 뭐라고?")
# Out:
# {'input': '내 이름이 뭐라고?',
#  'history': [HumanMessage(content='개의 조상이 뭐야?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='개의 조상은 늑대입니다. 개와 늑대는 같은 Canidae 가족에 속해 있으며, 공통 조상을 가지고 있습니다. 개는 수천 년 동안 인간과 함께 살아왔고, 다양한 품종으로 진화해왔습니다. 늑대와 개는 유전적으로 매우 유사하며, 개는 늑대의 일부 특징을 가지고 있습니다.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#   HumanMessage(content='김세종은 일본에 갈 수 있어?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='죄송해요, 김세종이 일본에 갈 수 있는지에 대한 정보는 제가 알 수 없어요.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#   HumanMessage(content='문윤성의 반댓말은?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='죄송해요, 문윤성의 반댓말에 대한 정보는 제가 알 수 없어요.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#   HumanMessage(content='예스규호는 어떤 일을 할 것 같아?', additional_kwargs={}, response_metadata={}),
# ...

# %% [markdown]
# ## ConversationSummaryMemory

# %%
from langchain_classic.memory import ConversationSummaryMemory

# %%
llm = ChatOpenAI(temperature=0.1)

memory = ConversationSummaryMemory(llm = llm)
# Out:
# C:\Users\Nobori\AppData\Local\Temp\ipykernel_21692\1680777014.py:3: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationSummaryMemory(llm = llm)

# %%
chain = ConversationChain(memory=memory, llm=llm)

# %%
chain.invoke("우리반의 길동이는 핸섬하고 몸도 좋고, 돈도 많고, 엄청나게 부지런한 사람이야!")
# Out:
# {'input': '우리반의 길동이는 핸섬하고 몸도 좋고, 돈도 많고, 엄청나게 부지런한 사람이야!',
#  'history': '',
#  'response': '길동이는 정말 대단한 사람이네요! 그의 성격과 능력을 칭찬하는 것 같아요. 부지런한 사람이라면 항상 성공할 수 있을 거예요.'}

# %%
chain.invoke("그리고 우리반의 동동이는 쟁반으로 사랑을 여기저기 나눠주는 사람이야")
# Out:
# {'input': '그리고 우리반의 동동이는 쟁반으로 사랑을 여기저기 나눠주는 사람이야',
#  'history': "The human praises their classmate Gil-dong, describing him as handsome, fit, wealthy, and incredibly hardworking. The AI agrees, complimenting Gil-dong's character and abilities, and believes that his diligence will lead to success.",
#  'response': '네, 동동이는 정말 친절하고 다정한 사람인 것 같아요. 사랑을 나눠주는 모습은 주변 사람들에게 큰 영감을 줄 거예요. 함께 공부하면서 그의 긍정적인 에너지를 느끼는 것이 정말 좋을 것 같아요.'}

# %%
print_memory()
# Out:
# {'history': "The human praises their classmate Gil-dong, describing him as handsome, fit, wealthy, and incredibly hardworking. The AI agrees, complimenting Gil-dong's character and abilities, and believes that his diligence will lead to success. The human then mentions their classmate Dong-dong, who is known for spreading love and kindness. The AI agrees, noting Dong-dong's kindness and believes that his actions will inspire those around him. Studying together and feeling Dong-dong's positive energy would be a great experience."}

# %%
chain.invoke("길동이는 어떤 사람이야?")
# Out:
# {'input': '길동이는 어떤 사람이야?',
#  'history': "The human praises their classmate Gil-dong, describing him as handsome, fit, wealthy, and incredibly hardworking. The AI agrees, complimenting Gil-dong's character and abilities, and believes that his diligence will lead to success. The human then mentions their classmate Dong-dong, who is known for spreading love and kindness. The AI agrees, noting Dong-dong's kindness and believes that his actions will inspire those around him. Studying together and feeling Dong-dong's positive energy would be a great experience.",
#  'response': '길동이는 잘생기고 건장하며 부유하고 끈기 있는 사람이에요. 그의 성격과 능력을 칭찬해요. 그의 끈기가 성공으로 이끌 것이라고 믿어요.'}

# %% [markdown]
# ## ConversationSummaryBufferMemory
# - 토큰 수를 제한하는 메모리

# %%
from langchain_classic.memory import ConversationSummaryBufferMemory

# %%
llm = ChatOpenAI(temperature=0.1)

memory = ConversationSummaryBufferMemory(
    llm = llm,
    return_messages=True,
    max_token_limit=50
)
# Out:
# C:\Users\Nobori\AppData\Local\Temp\ipykernel_21692\1260165670.py:3: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationSummaryBufferMemory(

# %%
chain = ConversationChain(memory=memory, llm=llm)

# %%
chain.invoke("뀨트북은 이제 보내줄 때가 된 것 같아")
chain.invoke("예스규호는 요즘 얼굴이 잘생긴 유중라인이야")
chain.invoke("약소훈도 요즘 핸섬한 유중라인으로 올라탔어")

chain.invoke("유중라인은 누구누구니?")
# Out:
# {'input': '유중라인은 누구누구니?',
#  'history': [SystemMessage(content='The human mentions that it might be time to send the laptop. The AI agrees that sending the laptop could be a good decision as it may provide better performance and features. The AI asks why the human wants to send the laptop. The human comments that Yes Gyu-ho has a handsome U-line face these days. The AI explains that the U-line face is a traditional Chinese facial shape with large eyes and well-defined double eyelids, suggesting that Yes Gyu-ho would have a striking appearance if he has that facial shape. The human adds that Yes Gyu-ho has been working out lately.', additional_kwargs={}, response_metadata={})],
#  'response': '유중라인은 중국 전통적인 얼굴 형태로 큰 눈과 뚜렷한 쌍꺼풀을 가진 얼굴 모양을 가리킵니다. 예스 규호가 그 얼굴 형태를 가지고 있다면 눈에 띄는 외모를 가질 것입니다. 최근에 운동을 하고 있다고 하셨죠.'}

# %%
print_memory()
# Out:
# {'history': [SystemMessage(content='The human mentions that it might be time to send the laptop. The AI agrees that sending the laptop could be a good decision as it may provide better performance and features. The AI asks why the human wants to send the laptop. The human comments that Yes Gyu-ho has a handsome U-line face these days. The AI explains that the U-line face is a traditional Chinese facial shape with large eyes and well-defined double eyelids, suggesting that Yes Gyu-ho would have a striking appearance if he has that facial shape. The human adds that Yes Gyu-ho has been working out lately. The human asks who 유중라인 is. The AI explains that 유중라인 refers to a traditional Chinese facial shape with large eyes and well-defined double eyelids, and suggests that Yes Gyu-ho would have a striking appearance if he had that facial shape.', additional_kwargs={}, response_metadata={})]}

# %% [markdown]
# ## ConversationKGMemory

# %%
from langchain_community.memory.kg import ConversationKGMemory

# %%
memory = ConversationKGMemory(llm=llm, return_messages=True)

# %%
chain = ConversationChain(memory=memory, llm=llm)

# %%
chain.invoke("세종이는 피부가 뽀얗게 변해서 왔어! 올림피아 사우나가 그런 피부에 도음을 줬어!")
chain.invoke("올림피아 사우나는 계란과 식혜를 팔아! 민균이는 식혜를 먹었고, 철민이는 구운계란을 먹었어!")

chain.invoke("세종이가 간 사우나에서 음식을 먹은 사람은?")
# Out:
# {'input': '세종이가 간 사우나에서 음식을 먹은 사람은?',
#  'history': [],
#  'response': '죄송합니다, 그 정보는 제가 알고 있는 정보에는 포함되어 있지 않습니다.'}

# %%
memory.load_memory_variables({"input": "올림피아 사우나는 계란과 식혜를 팔아! 민균이는 식혜를 먹었고, 철민이는 구운계란을 먹었어!"})
# Out:
# {'history': []}

# %%
chain.invoke("내 취미는 축구 야구 농구야")
chain.invoke("내가 좋아하는 음식은 돈까스 치킨 스테이크야")

chain.invoke("내가 좋아하는 음식은?")
# Out:
# {'input': '내가 좋아하는 음식은?',
#  'history': [],
#  'response': '죄송합니다, 그 정보는 제가 알 수 없습니다. 하지만 다른 질문이 있으면 도와드릴 수 있습니다!'}

# %% [markdown]
# ## LCEL 방법 권장

# %%
# MessagesPlaceholder: 프롬프트 안에 “대화 기록”을 끼워 넣는 자리표시 역할
# InMemoryChatMessageHistory: 대화 내용을 메모리에 저장
# RunnableWithMessageHistory: 체인 + 메모리 + 프롬프트를 자동으로 연결해주는 랩퍼
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

# %%
chat = ChatOpenAI(temperature=0.1)

# %%
chain = prompt | chat

chain_with_memory = RunnableWithMessageHistory(
    chain,
    get_history,
    input_messages_key="question",
    history_messages_key="chat_history",
)

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", """
        휴먼을 도와주는 AI도구입니다. 친절하게 답변하세요.
    """),
    # 저장소 메모리 위치
    MessagesPlaceholder(variable_name="chat_history"),
    ("human", "{question}"),
])

# %% [markdown]
# ## 저장소(메모리) 생성

# %%
# redis, db
store = {}

def get_history(session_id):
    if session_id not in store:
        store[session_id] = InMemoryChatMessageHistory()
    return store[session_id]

# %%
chain_with_memory = RunnableWithMessageHistory(
    chain,
    get_history,
    input_messages_key="question",
    history_messages_key="chat_history",
)

# %%
result = chain_with_memory.invoke(
    {
        "question": "내 이름은 길동이야"
    },
    config={"configurable": {"session_id": "user1"}}
)

# %%
print(result.content)
# Out:
# 안녕, 길동이! 무엇을 도와드릴까요?

# %%
print(store["user1"])
# Out:
# Human: 내 이름은 길동이야
# AI: 안녕, 길동이! 무엇을 도와드릴까요?

# %%
result = chain_with_memory.invoke(
    {
        "question": "난 오늘 저녁에 김치찌개를 먹을거야",
    },
    config={"configurable" : {"session_id": "user1"}}
)

# %%
result = chain_with_memory.invoke(
    {
        "question": "난 오늘 저녁에 무엇을 먹을 것 같아?",
    },
    config={"configurable" : {"session_id": "user1"}}
)

# %%
print(store["user1"])
# Out:
# Human: 내 이름은 길동이야
# AI: 안녕, 길동이! 무엇을 도와드릴까요?
# Human: 난 오늘 저녁에 김치찌개를 먹을거야
# AI: 김치찌개는 정말 맛있는 선택이네요! 맛있게 드세요! 뭔가 더 필요한 정보나 도움이 있으면 언제든지 말해주세요.
# Human: 난 오늘 저녁에 무엇을 먹을 것 같아?
# AI: 음식 선택은 개인 취향에 따라 다를 수 있어요. 어떤 음식을 좋아하시나요? 그 정보를 알려주시면 더 적합한 음식을 추천해 드릴 수 있어요.

# %%
chain_with_memory = RunnableWithMessageHistory(
    chain,
    get_history,
    input_messages_key="question",
    history_messages_key="chat_history"
).with_config(
    configurable={"session_id": "user2"}
)

# %%
result = chain_with_memory.invoke(
    {
        "question": "난 오늘 저녁에 무엇을 먹을 것 같아?",
    }
)

# %%
print(store["user2"])
# Out:
# Human: 난 오늘 저녁에 무엇을 먹을 것 같아?
# AI: 음식 선택은 개인 취향에 따라 다를 수 있지만, 몇 가지 제안을 드릴게요. 어떤 종류의 음식을 선호하시나요? 아시아 음식, 서양 음식, 혹은 다른 어떤 종류의 음식이든 좋다면 그에 맞는 음식을 추천해드릴게요.
